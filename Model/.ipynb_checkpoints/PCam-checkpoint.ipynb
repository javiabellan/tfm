# %% [markdown]
# # Notebook para la competición de Kaggle [Histopathologic Cancer Detection](https://www.kaggle.com/c/histopathologic-cancer-detection)
# Identify metastatic tissue in histopathologic scans of lymph node sections
#
# [Notebook de ayuda](https://www.kaggle.com/artgor/simple-eda-and-model-in-pytorch/notebook)

# %%
from javIA_oop import *

# %%
class CancerDataset(ImageDataset):

	def __init__(self, subset, transforms=False):
		dataset_dir = pathlib.Path("C:/Users/Javi/Desktop/Datasets/PCam")
		csv_file     = dataset_dir / "train_labels.csv"
		csv_df       = pd.read_csv(csv_file)

		self.image_dir  = dataset_dir / subset
		self.images     = (csv_df["id"]+".tif").values
		self.labels     = (csv_df["label"]).values
		self.labels_map = {0: "sano", 1: "cancer"}
		self.transforms = transforms

dataset = CancerDataset("train")
print("There are", len(dataset), "images in the dataset.")
# Out:
# There are 220025 images in the dataset.

# %%
dataset.plot_balance()

# %%
dataset.plot_images(columns=8, rows=3)

# %% [markdown]
# ## Add transforms

# %%
data_transforms = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data_transforms_test = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

dataset.transforms = data_transforms

# %% [markdown]
# ## Split in train/valid

# %%
dataset.labels
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data.sampler import SubsetRandomSampler

tr, val = train_test_split(list(dataset.labels), stratify=dataset.labels, test_size=0.1)

train_sampler = SubsetRandomSampler(list(tr.index))
valid_sampler = SubsetRandomSampler(list(val.index))

batch_size = 512

num_workers = 0
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
#test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, num_workers=num_workers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-53aef58c8262> in <module>
#       4 tr, val = train_test_split(list(dataset.labels), stratify=dataset.labels, test_size=0.1)
#       5
# ----> 6 train_sampler = SubsetRandomSampler(list(tr.index))
#       7 valid_sampler = SubsetRandomSampler(list(val.index))
#       8
#
# TypeError: 'builtin_function_or_method' object is not iterable
