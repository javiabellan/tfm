# %% [markdown]
# # Notebook para la competición de Kaggle [Histopathologic Cancer Detection](https://www.kaggle.com/c/histopathologic-cancer-detection)
# Identify metastatic tissue in histopathologic scans of lymph node sections
#
# [Notebook de ayuda](https://www.kaggle.com/artgor/simple-eda-and-model-in-pytorch/notebook)

# %%
from javIA_oop import *
# Out:
# AI framework by Javi based in PyTorch: 0.4.1

# %%
class CancerDataset(ImageDataset):

	def __init__(self, img_dir, csv_name, transforms=False, limit=False):
		dataset_dir = pathlib.Path("C:/Users/Javi/Desktop/Datasets/PCam")
		csv_df      = pd.read_csv(dataset_dir / csv_name)

		self.image_dir  = dataset_dir / img_dir
		self.images     = (csv_df["id"]+".tif").values
		self.labels     = (csv_df["label"]).values
		self.labels_map = {0: "sano", 1: "cancer"}
		self.transforms = transforms
		self.limit      = limit

dataset = CancerDataset("train", "train_labels.csv", limit=10000)
test_ds = CancerDataset("test", "sample_submission.csv")
print("There are", len(dataset), "images in the labeled dataset.")
print("There are", len(test_ds), "images in the test dataset.")
# Out:
# There are 220025 images in the labeled dataset.
# There are 57458 images in the test dataset.

# %%
dataset.plot_balance()

# %%
dataset.plot_images(columns=8, rows=3)

# %% [markdown]
# ## Add transforms

# %%
data_transforms = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data_transforms_test = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

dataset.transforms = data_transforms
test_ds.transforms = data_transforms_test

# %% [markdown]
# ## Split in train/valid

# %%
train_ds, valid_ds = dataset.split(val_size=0.1)
print("There are", len(train_ds), "images in the train dataset.")
print("There are", len(valid_ds), "images in the validation dataset.")
# Out:
# There are 198022 images in the train dataset.
# There are 22003 images in the validation dataset.

# %% [markdown]
# # Train

# %%
dl = DeepLearner("resnet18", train_ds, valid_ds, test_ds, batch_size=512) # batch_size=512

# %%
#epochs         = [0,1,2,3] #[0, 15, 30, 35]
#learning_rates = [0, 0.1, 0.005, 0]
epochs         = [0,1]
learning_rates = [0.1, 0.01]
plot_lr(epochs, learning_rates)

# %%
dl.train(epochs, learning_rates)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# Epoch	Time	LearRate	T_loss	T_accu		V_loss	V_accu<p>----------------------------------------------------------------------<p>epoch<p>
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='387', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-354dd2268a6a> in <module>
# ----> 1 dl.train(epochs, learning_rates)
#
# ~\Desktop\tfm\Model\javIA_oop.py in train(self, epochs, learning_rates)
#     445                         #self.train_batches.dataset.set_random_choices()
#     446                         lrs = (lr_schedule(x)/self.batch_size for x in np.arange(epoch, epoch+1, 1/len(self.train_batches)))
# --> 447                         train_stats, train_time = self.train_epoch(mb, lrs, {'loss': [], 'correct': []}), t()
#     448                         valid_stats, valid_time = self.valid_epoch(mb,      {'loss': [], 'correct': []}), t()
#     449
#
# ~\Desktop\tfm\Model\javIA_oop.py in train_epoch(self, mb, lrs, stats)
#     396         def train_epoch(self, mb, lrs, stats):
#     397                 self.model.train(True)
# --> 398                 for lr, batch in zip(lrs, progress_bar(self.train_batches, parent=mb)):
#     399                         loss = self.forward(batch, stats)
#     400                         self.backward(lr, loss)
#
# ~\Anaconda3\lib\site-packages\fastprogress\fastprogress.py in __iter__(self)
#      63         self.update(0)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#      67                 if self.auto_update: self.update(i+1)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Desktop\tfm\Model\javIA_oop.py in __getitem__(self, idx)
#      43         def __getitem__(self, idx):
#      44                 img_name = self.image_dir / self.images[idx]
# ---> 45                 image = PIL.Image.open(img_name)
#      46                 if self.transforms: image = self.transforms(image)
#      47                 label = self.labels[idx]
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2607
#    2608     if filename:
# -> 2609         fp = builtins.open(filename, "rb")
#    2610         exclusive_fp = True
#    2611
#
# KeyboardInterrupt:

# %% [markdown]
# # Test

# %%
def test_epoch(dl):
	preds = []
	dl.model.train(False)
	for batch in tqdm(dl.test_batches):
		inputs  = batch[0].to(dl.device)
		labels  = batch[1].to(dl.device)
		if dl.half_prec:
			inputs, labels = inputs.half(), labels.half()
		output = dl.model(inputs)
		pr = output.detach().cpu().numpy()
		for i in pr:
			preds.append(i)
	return preds

# %%
preds = test_epoch(dl)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 113/113 [03:38<00:00,  2.17s/it]

# %%
test_preds = pd.DataFrame({'id': test_ds.images, 'label': preds})

# %%
test_preds['id'] = test_preds['id'].apply(lambda x: x.split('.')[0])

# %%
test_preds.head()
# Out:
#                                          id     label
# 0  0b2ea2a822ad23fdb1b5dd26653da899fbd2c0d5  0.009773
# 1  95596b92e5066c5c52466c90b69ff089b39f2737  0.270020
# 2  248e6738860e2ebcf6258cdc1f32f299e0c76914  0.045135
# 3  2c35657e312966e9294eac6841726ff3a748febf  0.647461
# 4  145782eb7caa1c516acbe2eda34d9a3f31c41fd6  0.062866

# %%
test_preds.to_csv('PCam_sub.csv', index=False)
