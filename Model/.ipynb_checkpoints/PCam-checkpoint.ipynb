# %% [markdown]
# # Notebook para la competición de Kaggle [Histopathologic Cancer Detection](https://www.kaggle.com/c/histopathologic-cancer-detection)
# Identify metastatic tissue in histopathologic scans of lymph node sections
#
# [Notebook de ayuda](https://www.kaggle.com/artgor/simple-eda-and-model-in-pytorch/notebook)

# %%
from javIA_oop import *
# Out:
# AI framework by Javi based in PyTorch: 0.4.1

# %%
class CancerDataset(ImageDataset):

	def __init__(self, img_dir, csv_name, transforms=False, limit=False):
		dataset_dir = pathlib.Path("C:/Users/Javi/Desktop/Datasets/PCam")
		csv_df      = pd.read_csv(dataset_dir / csv_name)

		self.image_dir  = dataset_dir / img_dir
		self.images     = (csv_df["id"]+".tif").values
		self.labels     = (csv_df["label"]).values
		self.labels_map = {0: "sano", 1: "cancer"}
		self.transforms = transforms
		self.limit      = limit

dataset = CancerDataset("train", "train_labels.csv")
test_ds = CancerDataset("test", "sample_submission.csv")
print("There are", len(dataset), "images in the labeled dataset.")
print("There are", len(test_ds), "images in the test dataset.")
# Out:
# There are 10000 images in the labeled dataset.
# There are 57458 images in the test dataset.

# %%
dataset.plot_balance()

# %%
dataset.plot_images(columns=8, rows=3)

# %% [markdown]
# ## Add transforms

# %%
data_transforms = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data_transforms_test = transforms.Compose([
    #transforms.CenterCrop(32),
    transforms.Pad(64, padding_mode='reflect'),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

dataset.transforms = data_transforms
test_ds.transforms = data_transforms_test

# %% [markdown]
# ## Split in train/valid

# %%
train_ds, valid_ds = dataset.split(val_size=0.1)
print("There are", len(train_ds), "images in the train dataset.")
print("There are", len(valid_ds), "images in the validation dataset.")
# Out:
# There are 10000 images in the train dataset.
# There are 512 images in the validation dataset.

# %% [markdown]
# # Train

# %%
dl = DeepLearner("resnet18", train_ds, valid_ds, test_ds, batch_size=512) # batch_size=512

# %%
#epochs         = [0,1,2,3] #[0, 15, 30, 35]
#learning_rates = [0, 0.1, 0.005, 0]
epochs         = [0, 0.2, 1]
learning_rates = [0.01, 0.1,0.01]
plot_lr(epochs, learning_rates)

# %%
#dl.train_ds.limit=512*2
#dl.valid_ds.limit=512*2
dl.train(epochs, learning_rates)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# Epoch	Time	LearRate	T_loss	T_accu		V_loss	V_accu<p>----------------------------------------------------------------------<p>epoch<p>
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-5ce6cdec262d> in <module>
#       1 dl.train_ds.limit=512*2
#       2 dl.valid_ds.limit=512*2
# ----> 3 dl.train(epochs, learning_rates)
#
# ~\Desktop\tfm\Model\javIA_oop.py in train(self, epochs, learning_rates)
#     451                         #self.train_batches.dataset.set_random_choices()
#     452                         lrs = (lr_schedule(x)/self.batch_size for x in np.arange(epoch, epoch+1, 1/len(self.train_batches)))
# --> 453                         train_stats, train_time = self.train_epoch(mb, lrs), t()
#     454                         valid_stats, valid_time = self.valid_epoch(mb,    ), t()
#     455
#
# ~\Desktop\tfm\Model\javIA_oop.py in train_epoch(self, mb, lrs)
#     392                 for lr, batch in zip(lrs, progress_bar(self.train_batches, parent=mb)):
#     393                         input, target = self.get_batch(batch)
# --> 394                         output        = self.model(input)
#     395                         metric        = self.metric(output, target)
#     396                         loss          = self.criterion(output, target)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torchvision\models\resnet.py in forward(self, x)
#     143
#     144         x = self.layer1(x)
# --> 145         x = self.layer2(x)
#     146         x = self.layer3(x)
#     147         x = self.layer4(x)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torchvision\models\resnet.py in forward(self, x)
#      43         out = self.relu(out)
#      44
# ---> 45         out = self.conv2(out)
#      46         out = self.bn2(out)
#      47
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: CUDA error: out of memory

# %%
plt_mem()

# %% [markdown]
# # Test

# %%
#dl.load_model()
def test_epoch(dl):
	preds = []
	dl.model.train(False)
	for batch in tqdm(dl.test_batches):
		inputs  = batch[0].to(dl.device)
		labels  = batch[1].to(dl.device)
		if dl.half_prec:
			inputs, labels = inputs.half(), labels.half()
		output = dl.model(inputs)
		pr = output.detach().cpu().numpy()
		for i in pr:
			preds.append(i)
	return preds

# %%
preds = dl.test_epoch()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 113/113 [04:50<00:00,  2.09s/it]

# %%
test_preds = pd.DataFrame({'id': test_ds.images, 'label': preds})

# %%
test_preds['id'] = test_preds['id'].apply(lambda x: x.split('.')[0])

# %%
test_preds
# Out:
#                                              id     label
# 0      0b2ea2a822ad23fdb1b5dd26653da899fbd2c0d5 -0.346191
# 1      95596b92e5066c5c52466c90b69ff089b39f2737 -0.125366
# 2      248e6738860e2ebcf6258cdc1f32f299e0c76914 -0.617676
# 3      2c35657e312966e9294eac6841726ff3a748febf -0.249146
# 4      145782eb7caa1c516acbe2eda34d9a3f31c41fd6 -0.156006
# 5      725dabe6ecccc68b958a2c7dd75bcbf362c7cb03 -0.521973
# 6      aa0307865281d4484ddf8c637c348292968b93a7 -0.201660
# 7      f4e5dc9c949920f1b3362982e15e99bf6f3ef83b -0.055542
# 8      95e08c9cedc28a9b4a86f4fc1e06c1972134be08 -1.028320
# 9      ee1f5345a8d4e28403b7e61b97b5f76c201ce9cb -0.709961
# 10     14b1e9a72e27a35f13056db611feb3c8825916f4 -0.575684
# 11     4f7710b24b9b776f6bfc89fad5469592d18e5431 -0.565430
# 12     2b0668109c7c446c94d29e1b554016b486e84bde -1.023438
# 13     8dbd712b5b5e86c18c97da3fb7845cfe23cdf1c5 -0.200928
# 14     0084317dbb3398aed9f7c915c2cdef5a07ada5be -0.342285
# 15     5685c695bb0926d8ce434bb787a58affdc9277df -0.493164
# 16     715ea4b61896620422f4c9c954db514077633745 -0.563965
# 17     a218c12c700277dd50b2da4e0e3a0089d5094186 -0.246948
# 18     c0a44513db67635cc99370f24d962e272dbf7a11 -0.883789
# 19     dd52e9ad03e746aff71b1d81c1cf168ec6dcdf57 -0.182007
# 20     a67f22a204960680de09f88c9a588014e78e314c  0.105896
# 21     5a895b4562c4d67d194b76094690a8cba046f9f3 -0.384033
# 22     09f704e216dab50f7d759746bb1f132cc7b59939 -0.839844
# 23     e1d48393c5fa0bca3d3469f8a42e1991f2939a3d -0.547363
# 24     42301acb5c16684fbde86e0210f19f6adf232316 -0.342285
# 25     4c3b7d71422fe2c35153a821c84538516ee89573  0.016891
# 26     edf908d325da428766464beb035c744e589e2ba0 -0.666016
# 27     c68144b44b49d96d4b2e1870f854781a84ec3e20 -0.067139
# 28     81d0aa3c20f021c2fc12a79c359ea29fa499425f -0.370605
# 29     564804ca8f0e05b7790108a24e7f2a36f1732375  0.350342
# ...                                         ...       ...
# 57428  c3936a5ab82c8429d337c2af505d12e8fed53800  0.328857
# 57429  3a51838cb2d914b1eae479ed07887a25ad898130 -0.238647
# 57430  5cd2c886445fa12b1a5fd7476f59f6b9ff641048 -0.196777
# 57431  73b6d3a082011e64bff624fe718bb66cc7757572  0.034760
# 57432  5bb1f5a647fed58bfa69a820f16c959e4f8e418b -0.727539
# 57433  cbfe076d09dbbfe899d2276d38d1e6b2669e06b9 -0.024292
# 57434  3f713d1d1b0e8cd18daf3bc014b21f09f243ac4d -0.391113
# 57435  5e6e3443a9145a43e10e4fcc35df3fd8bc3c4411 -0.634277
# 57436  aaff0630a066416f374cd2e65a169d8378840376 -0.532227
# 57437  a36a9295354c700739b369dd7de4df54e801c185 -0.144165
# 57438  86cbac8eef45d436a8b1c7469ada0894f0b684cc -0.526855
# 57439  64c1b67a3d4409c3de1da54b88771da63620dd53 -0.051788
# 57440  da50fba013af3e308867f47183e7d037f574dc10 -0.560059
# 57441  b0f5c94b69b5c76a5f0a9364c5d102826d29e0b3 -0.477783
# 57442  8464c48f09addf99e79aee5422a66cfff48c2929 -0.466309
# 57443  f18483fb465cd92c73b5f5e775f23b58cc5b2d36 -0.005348
# 57444  d92e5dc32ff59711a94e0f4edfcd6a8b2eff583f -0.002735
# 57445  7e43b15f9b04dfa36a80ffc8787a2115fe3633df -0.524414
# 57446  1817497e85ef6d779852d4bae488b45fbccb4305 -0.064270
# 57447  7c553e582d5a67f2bc90273d8f62940f6d46aba0 -0.026886
# 57448  5481ea07d17fed3a807294a1c2ddbba2a64eb9e3 -0.778320
# 57449  d5b3051b33d56ae6b46069225739ba2005d3ae61 -0.404785
# 57450  69097bf5ae9632515d2e70c7cd3880ea7980820c  0.161865
# 57451  a3c0f54a1e82f1bb3f9527eb619cec2bb229fa5d  0.013725
# 57452  f93cadad45c3d7763af25d3412bd0019a95fa0f1 -0.426514
# 57453  061847314ded6f81e1cd670748bfa2003442c9c7 -0.279297
# 57454  6f3977130212641fd5808210015a609c658dcbff -0.353760
# 57455  46935f247278539eca74b54d07d666efb528a753 -0.015617
# 57456  a09bcae08a82120183352e0e869181b2911d3dc1 -0.382812
# 57457  d29233dc0b90c2e1a8fcedbc3e1234c3d4dbd55b -0.696289
#
# [57458 rows x 2 columns]

# %%
test_preds.to_csv('PCam_sub.csv', index=False)
