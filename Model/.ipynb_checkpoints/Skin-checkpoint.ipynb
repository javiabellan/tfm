# %% [markdown]
# # Imports

# %%
from javIA_oop import *
# Out:
# AI framework by Javi based in PyTorch: 0.4.1

# %% [markdown]
# # Load data

# %%
class SkinDataset(ImageDataset):

	def __init__(self, subset, transforms=False, limit=False):
		dataset_dir = pathlib.Path("D:/Datasets/TFM/ISIC-2017")
		csv_file    = dataset_dir / ("ground_truth_"+subset+".csv")
		csv_df      = pd.read_csv(csv_file)

		self.image_dir  = dataset_dir / ("data_"+subset)
		self.images     = (csv_df["image_id"]+".jpg").values
		self.labels     = csv_df.apply(self.get_label, axis=1).values
		self.labels_map = {0:"melanoma", 1:"seborrheic", 2:"healthy"}
		self.transforms = transforms
		self.limit      = limit

	def get_label(self, row):    
		label = row[1:3].values.tolist()
		if   label[0]==1.0: label=0   #"melanoma"
		elif label[1]==1.0: label=1   #"seborrheic_keratosis"
		else:               label=2   #"healthy"
		return label


dataset    = {subset: SkinDataset(subset) for subset in ["train", "valid", "test"]}
{print("There are", len(dataset[subset]), "images in the "+subset+" dataset.") for subset in ["train", "valid", "test"]};
# Out:
# There are 2000 images in the train dataset.
# There are 150 images in the valid dataset.
# There are 600 images in the test dataset.

# %% [markdown]
# # Check if data is balanced

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
for i, subset in enumerate(["train", "valid", "test"]):
    dataset[subset].plot_balance(axs[i], title=subset)

# %% [markdown]
# # Show data

# %%
dataset["train"].plot_images(columns=6, rows=3)

# %% [markdown]
# # Min sizes of the images

# %%
for subset in ["train", "valid", "test"]:
    print(subset)
    min_sizes = dataset[subset].get_min_sizes()
    print("\tMinimun width  =",min_sizes['min_w'])
    print("\tMinimun height =",min_sizes['min_h'])
# Out:
# train
# 	Minimun width   = 576
# 	Minimun height  = 540
# valid
# 	Minimun width   = 1024
# 	Minimun height  = 768
# test
# 	Minimun width   = 639
# 	Minimun height  = 602

# %% [markdown]
# # Mean and std

# %%
dataset["valid"].get_mean_and_std()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 150/150 [01:02<00:00,  1.07s/it]
# {'mean': [tensor(0.6926), tensor(0.5605), tensor(0.5103)],
#  'std': [tensor(0.0934), tensor(0.0958), tensor(0.1102)]}

# %% [markdown]
# # Add transforms

# %%
data_transforms = transforms.Compose([
    transforms.CenterCrop(320),
    #transforms.Pad(64, padding_mode='reflect'),
    #transforms.RandomHorizontalFlip(),
    #transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

dataset["train"].transforms = data_transforms
dataset["valid"].transforms = data_transforms

# %%
#dl = DeepLearner("resnet18", dataset["train"], dataset["valid"], batch_size=32, half_prec=False)
dl = DeepLearner("resnet18", dataset["train"], dataset["valid"], batch_size=32, half_prec=False, balance=True)

# %%
dl.findLR(start_lr=1e-6, end_lr=1e-2)
# Out:
#  14%|███████████▏                                                                    | 14/100 [01:03<06:22,  4.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c770f19e15b3> in <module>
# ----> 1 dl.findLR(start_lr=1e-6, end_lr=1e-2)
#
# ~\Desktop\tfm\Model\javIA_oop.py in findLR(self, start_lr, end_lr, num_it)
#     578                 for batch_num in tqdm(range(num_it)):
#     579
# --> 580                         inputs, targets = next(iter(self.train_batches))
#     581
#     582                         self.update_lr(lr)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Desktop\tfm\Model\javIA_oop.py in __getitem__(self, idx)
#      44                 if type(idx)==torch.Tensor: idx = idx.item() # TODO: bug of WeightedRandomSampler?
#      45                 img_name = self.image_dir / self.images[idx]
# ---> 46                 image = PIL.Image.open(img_name)
#      47                 if self.transforms: image = self.transforms(image)
#      48                 label = self.labels[idx]
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2607
#    2608     if filename:
# -> 2609         fp = builtins.open(filename, "rb")
#    2610         exclusive_fp = True
#    2611
#
# KeyboardInterrupt:

# %% [markdown]
# # Training
#
# #### Data
# - Preprocess: Subtracting global mean
# - Deal imbalance: Oversampling minority classes (only in train set)
# - Augmentations: Shear, rotation, ...
#
# #### Model: Resnet18
# - Resnet or Inception v3
# - Last new layers:
#   1. Global average pooling layer
#   2. Fully connected layer with 1024 nodes and activated with ReLU.
#   3. Fully connected layer with 1 node output
# - Batch size: 32
# - Loss: binary_crossentropy
# - Metric: accuracy
#
#
# #### 1st traininig
#
# - Unfreeze only the last new layers.
# - Input size: 128x128 (resized)
# - Epochs: 20
# - Optimizer: Rmsprop
# - Adaptive learning rate: Reduce the lr by a factor of 10, after 5 epochs of no accuracy improvement on the validation set.
#
# #### 2nd training
#
# - Unfreeze also the last two Inception/resnet blocks.
# - Input size: 299x299 (resized)
# - Epochs: EarlyStopping(monitor='val_acc', min_delta=0.01, patience=50, verbose=1, mode='auto')
# - Optimizer: stochastic gradient descent
# - Learning rate: 1e-04,
# - Momentum: 0.9
# - Adaptive learning rate: ReduceLROnPlateau(monitor='val_acc', factor=0.1, patience=25, verbose=1))
#
# ## Evaluation
#
# 2 separate binary image classification tasks:
#
# - Task 1 (melanoma vs nevus+seborrheic):
#   - Val AUC: 0.76..0.78
#   - Test Acc: 0.83
#   - Avg Prec: 0.43
# - Task 2 (melanoma+nevus vs seborrheic):
#   - Val AUC: 0.84..0.87
#   - Test Acc: 0.92
#   - Avg Prec: 0.66
# ---

# %% [markdown]
# # Train
# - Model: Resnet18

# %%
dl = DeepLearner(dataset, "resnet18")
epochs         = [0,1,2,3] #[0, 15, 30, 35]
learning_rates = [0, 0.1, 0.005, 0]
dl.train(epochs, learning_rates)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# Epoch	Time	LearRate	T_loss	T_accu		V_loss	V_accu<p>----------------------------------------------------------------------<p>epoch<p>
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='250', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5eadea99b7ff> in <module>
#       1 epochs         = [0,1,2,3] #[0, 15, 30, 35]
#       2 learning_rates = [0, 0.1, 0.005, 0]
# ----> 3 dl.train(epochs, learning_rates)
#
# ~\Desktop\tfm\Model\javIA_oop.py in train(self, epochs, learning_rates)
#     316                         #self.train_batches.dataset.set_random_choices()
#     317                         lrs = (lr_schedule(x)/self.batch_size for x in np.arange(epoch, epoch+1, 1/len(self.train_batches)))
# --> 318                         train_stats, train_time = self.train_epoch(mb, lrs, {'loss': [], 'correct': []}), t()
#     319                         valid_stats, valid_time = self.valid_epoch(mb,      {'loss': [], 'correct': []}), t()
#     320
#
# ~\Desktop\tfm\Model\javIA_oop.py in train_epoch(self, mb, lrs, stats)
#     285         def train_epoch(self, mb, lrs, stats):
#     286                 self.model.train(True)
# --> 287                 for lr, batch in zip(lrs, progress_bar(self.train_batches, parent=mb)):
#     288                         loss = self.forward(batch, stats)
#     289                         self.backward(lr, loss)
#
# ~\Anaconda3\lib\site-packages\fastprogress\fastprogress.py in __iter__(self)
#      63         self.update(0)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#      67                 if self.auto_update: self.update(i+1)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# ~\Desktop\tfm\Model\javIA_oop.py in __getitem__(self, idx)
#      43                 img_name = self.image_dir / self.images[idx]
#      44                 image = PIL.Image.open(img_name)
# ---> 45                 if self.transforms: image = self.transforms(image)
#      46                 label = self.labels[idx]
#      47                 return image, label
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      47     def __call__(self, img):
#      48         for t in self.transforms:
# ---> 49             img = t(img)
#      50         return img
#      51
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#     213             PIL Image: Cropped image.
#     214         """
# --> 215         return F.center_crop(img, self.size)
#     216
#     217     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in center_crop(img, output_size)
#     307     i = int(round((h - th) / 2.))
#     308     j = int(round((w - tw) / 2.))
# --> 309     return crop(img, i, j, th, tw)
#     310
#     311
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in crop(img, i, j, h, w)
#     297         raise TypeError('img should be PIL Image. Got {}'.format(type(img)))
#     298
# --> 299     return img.crop((j, i, j + w, i + h))
#     300
#     301
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in crop(self, box)
#    1110             return self.copy()
#    1111
# -> 1112         self.load()
#    1113         return self._new(self._crop(self.im, box))
#    1114
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     237
#     238                             b = b + s
# --> 239                             n, err_code = decoder.decode(b)
#     240                             if n < 0:
#     241                                 break
#
# KeyboardInterrupt:
