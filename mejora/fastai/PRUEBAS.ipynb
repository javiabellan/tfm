# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64

# %%
data = ImageDataBunch.from_name_re().normalize(imagenet_stats)
# Out:
# Help on method from_name_re in module fastai.vision.data:
#
# from_name_re(path: Union[pathlib.Path, str], fnames: Collection[pathlib.Path], pat: str, valid_pct: float = 0.2, **kwargs) method of builtins.type instance
#     Create from list of `fnames` in `path` with re expression `pat`.

# %%
Image.open('../Datasets/ISIC-2017/example.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1158x334 at 0x207606EB3C8>

# %% [markdown]
# - [x] Finish my changes
# - [ ] Push my commits to GitHub
# - [ ] Open a pull request
